# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
udemy='https://www.udemy.com/'

# %%
udemy_doc=requests.get(udemy).text

# %%
soup=BeautifulSoup(udemy_doc,'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
requests.get(udemy).status_code
# Out:
# 200

# %%
<div class="carousel--container--37Pr-"><div id="course-unit-container-NewestcoursesinMicrosoftAzure" aria-live="polite" class="course-unit--grid--3KXpZ  carousel--scroll-port--EKRiq carousel--grid--35Xll carousel--scroll-lock--38Od9"><div data-index="0" class="carousel--scroll-item--1O-L9"><div><div class="popper--popper--2r2To popper--popper-hover--3YydE"><a id="u517-popper-trigger--58" tabindex="0" aria-expanded="false" href="/course/microsoft-azure-fundamentals-certification-training/" class="udlite-custom-focus-visible browse-course-card--link--3KIkQ" style="display: block;"><div data-purpose="container" class="course-card--container--1QM2W course-card--medium--Fdbz0"><div class="course-card--image-wrapper--1F9ny"><img alt="" width="240" height="135" class="course-card--course-image--3QvbQ browse-course-card--image--35hYN" src="https://img-c.udemycdn.com/course/240x135/4183528_869c.jpg" srcset="https://img-c.udemycdn.com/course/240x135/4183528_869c.jpg 1x, https://img-c.udemycdn.com/course/480x270/4183528_869c.jpg 2x"></div><div class="course-card--main-content--2XqiY course-card--has-price-text--1c0ze"><div class="udlite-focus-visible-target udlite-heading-md course-card--course-title--vVEjC">Microsoft Azure Fundamentals</div><div class="udlite-text-xs course-card--instructor-list--nH1OC" data-purpose="safely-set-inner-html:course-card:visible-instructors">Uplatz Training</div><div class="course-card--row--29Y0w"><span class="star-rating--star-wrapper--1QyBg"><span class="udlite-sr-only">Rating: 4.2 out of 5</span><span class="udlite-heading-sm star-rating--rating-number--2o8YM" aria-hidden="true" data-purpose="rating-number">4.2</span><svg aria-hidden="true" width="100%" height="100%" viewBox="0 0 70 14" fill="none" xmlns="http://www.w3.org/2000/svg"><mask id="u517-star-rating-mask--60" data-purpose="star-rating-mask"><rect x="0" y="0" width="80%" height="100%" fill="white"></rect></mask><g class="star-rating--star-filled--24lmQ" mask="url(#u517-star-rating-mask--60)" data-purpose="star-filled"><use xlink:href="#icon-rating-star" width="14" height="14" x="0"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="14"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="28"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="42"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="56"></use></g><g fill="transparent" class="star-rating--star-bordered--1EkpX" stroke-width="2" data-purpose="star-bordered"><use xlink:href="#icon-rating-star" width="12" height="12" x="1" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="15" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="29" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="43" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="57" y="1"></use></g></svg></span><span aria-label="38 reviews" class="udlite-text-xs course-card--reviews-text--1yloi">(38)</span></div><div class="price-text--container--103D9 course-card--price-text-container--XIYmk" data-purpose="price-text-container"><div class="price-text--price-part--2npPm course-card--discount-price--1bQ5Q udlite-heading-md" data-purpose="course-price-text"><span class="udlite-sr-only">Current price</span><span><span>₹385</span></span></div><div class="price-text--price-part--2npPm price-text--original-price--1sDdx course-card--list-price--3RTcj udlite-text-sm" data-purpose="original-price-container"><div data-purpose="course-old-price-text"><span class="udlite-sr-only">Original Price</span><span><s><span>₹1,280</span></s></span></div></div></div><div class="udlite-badge udlite-heading-xs udlite-badge-new ">New</div></div></div></a></div></div></div><div data-index="1" class="carousel--scroll-item--1O-L9"><div><div class="popper--popper--2r2To popper--popper-hover--3YydE"><a id="u517-popper-trigger--61" tabindex="0" aria-expanded="false" href="/course/microsoft-azure-advanced-services/" class="udlite-custom-focus-visible browse-course-card--link--3KIkQ" style="display: block;"><div data-purpose="container" class="course-card--container--1QM2W course-card--medium--Fdbz0"><div class="course-card--image-wrapper--1F9ny"><img alt="" width="240" height="135" class="course-card--course-image--3QvbQ browse-course-card--image--35hYN" src="https://img-c.udemycdn.com/course/240x135/4090568_0a0a_2.jpg" srcset="https://img-c.udemycdn.com/course/240x135/4090568_0a0a_2.jpg 1x, https://img-c.udemycdn.com/course/480x270/4090568_0a0a_2.jpg 2x"></div><div class="course-card--main-content--2XqiY course-card--has-price-text--1c0ze"><div class="udlite-focus-visible-target udlite-heading-md course-card--course-title--vVEjC">Microsoft Azure: Mastering Advanced Services</div><div class="udlite-text-xs course-card--instructor-list--nH1OC" data-purpose="safely-set-inner-html:course-card:visible-instructors">Memi Lavi</div><div class="course-card--row--29Y0w"><span class="star-rating--star-wrapper--1QyBg"><span class="udlite-sr-only">Rating: 4.7 out of 5</span><span class="udlite-heading-sm star-rating--rating-number--2o8YM" aria-hidden="true" data-purpose="rating-number">4.7</span><svg aria-hidden="true" width="100%" height="100%" viewBox="0 0 70 14" fill="none" xmlns="http://www.w3.org/2000/svg"><mask id="u517-star-rating-mask--63" data-purpose="star-rating-mask"><rect x="0" y="0" width="90%" height="100%" fill="white"></rect></mask><g class="star-rating--star-filled--24lmQ" mask="url(#u517-star-rating-mask--63)" data-purpose="star-filled"><use xlink:href="#icon-rating-star" width="14" height="14" x="0"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="14"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="28"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="42"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="56"></use></g><g fill="transparent" class="star-rating--star-bordered--1EkpX" stroke-width="2" data-purpose="star-bordered"><use xlink:href="#icon-rating-star" width="12" height="12" x="1" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="15" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="29" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="43" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="57" y="1"></use></g></svg></span><span aria-label="6 reviews" class="udlite-text-xs course-card--reviews-text--1yloi">(6)</span></div><div class="price-text--container--103D9 course-card--price-text-container--XIYmk" data-purpose="price-text-container"><div class="price-text--price-part--2npPm course-card--discount-price--1bQ5Q udlite-heading-md" data-purpose="course-price-text"><span class="udlite-sr-only">Current price</span><span><span>₹385</span></span></div><div class="price-text--price-part--2npPm price-text--original-price--1sDdx course-card--list-price--3RTcj udlite-text-sm" data-purpose="original-price-container"><div data-purpose="course-old-price-text"><span class="udlite-sr-only">Original Price</span><span><s><span>₹6,400</span></s></span></div></div></div><div class="udlite-badge udlite-heading-xs udlite-badge-hot-and-new ">Hot &amp; new</div></div></div></a></div></div></div><div data-index="2" class="carousel--scroll-item--1O-L9"><div><div class="popper--popper--2r2To popper--popper-hover--3YydE"><a id="u517-popper-trigger--64" tabindex="0" aria-expanded="false" href="/course/ml-flask-deployment-on-azure/" class="udlite-custom-focus-visible browse-course-card--link--3KIkQ" style="display: block;"><div data-purpose="container" class="course-card--container--1QM2W course-card--medium--Fdbz0"><div class="course-card--image-wrapper--1F9ny"><img alt="" width="240" height="135" class="course-card--course-image--3QvbQ browse-course-card--image--35hYN" src="https://img-c.udemycdn.com/course/240x135/4192532_a729.jpg" srcset="https://img-c.udemycdn.com/course/240x135/4192532_a729.jpg 1x, https://img-c.udemycdn.com/course/480x270/4192532_a729.jpg 2x"></div><div class="course-card--main-content--2XqiY course-card--has-price-text--1c0ze"><div class="udlite-focus-visible-target udlite-heading-md course-card--course-title--vVEjC">Machine Learning Flask Deployment on Microsoft Azure 2021</div><div class="udlite-text-xs course-card--instructor-list--nH1OC" data-purpose="safely-set-inner-html:course-card:visible-instructors">Muhammad Huzaifa Shahbaz</div><div class="course-card--row--29Y0w"><span class="star-rating--star-wrapper--1QyBg"><span class="udlite-sr-only">Rating: 4.9 out of 5</span><span class="udlite-heading-sm star-rating--rating-number--2o8YM" aria-hidden="true" data-purpose="rating-number">4.9</span><svg aria-hidden="true" width="100%" height="100%" viewBox="0 0 70 14" fill="none" xmlns="http://www.w3.org/2000/svg"><mask id="u517-star-rating-mask--66" data-purpose="star-rating-mask"><rect x="0" y="0" width="100%" height="100%" fill="white"></rect></mask><g class="star-rating--star-filled--24lmQ" mask="url(#u517-star-rating-mask--66)" data-purpose="star-filled"><use xlink:href="#icon-rating-star" width="14" height="14" x="0"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="14"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="28"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="42"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="56"></use></g><g fill="transparent" class="star-rating--star-bordered--1EkpX" stroke-width="2" data-purpose="star-bordered"><use xlink:href="#icon-rating-star" width="12" height="12" x="1" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="15" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="29" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="43" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="57" y="1"></use></g></svg></span><span aria-label="5 reviews" class="udlite-text-xs course-card--reviews-text--1yloi">(5)</span></div><div class="price-text--container--103D9 course-card--price-text-container--XIYmk" data-purpose="price-text-container"><div class="price-text--price-part--2npPm course-card--discount-price--1bQ5Q udlite-heading-md" data-purpose="course-price-text"><span class="udlite-sr-only">Current price</span><span><span>₹385</span></span></div><div class="price-text--price-part--2npPm price-text--original-price--1sDdx course-card--list-price--3RTcj udlite-text-sm" data-purpose="original-price-container"><div data-purpose="course-old-price-text"><span class="udlite-sr-only">Original Price</span><span><s><span>₹1,600</span></s></span></div></div></div><div class="udlite-badge udlite-heading-xs udlite-badge-new ">New</div></div></div></a></div></div></div><div data-index="3" class="carousel--scroll-item--1O-L9"><div><div class="popper--popper--2r2To popper--popper-hover--3YydE"><a id="u517-popper-trigger--67" tabindex="0" aria-expanded="false" href="/course/microsoft-azure-fundamentals-administration-and-ai/" class="udlite-custom-focus-visible browse-course-card--link--3KIkQ" style="display: block;"><div data-purpose="container" class="course-card--container--1QM2W course-card--medium--Fdbz0"><div class="course-card--image-wrapper--1F9ny"><img alt="" width="240" height="135" class="course-card--course-image--3QvbQ browse-course-card--image--35hYN" src="https://img-c.udemycdn.com/course/240x135/4188144_4ab5_5.jpg" srcset="https://img-c.udemycdn.com/course/240x135/4188144_4ab5_5.jpg 1x, https://img-c.udemycdn.com/course/480x270/4188144_4ab5_5.jpg 2x"></div><div class="course-card--main-content--2XqiY course-card--has-price-text--1c0ze"><div class="udlite-focus-visible-target udlite-heading-md course-card--course-title--vVEjC">Microsoft Azure Fundamentals, Administration and AI</div><div class="udlite-text-xs course-card--instructor-list--nH1OC" data-purpose="safely-set-inner-html:course-card:visible-instructors">Mohammed Tajvir Chowdhury</div><div class="course-card--row--29Y0w"><span class="star-rating--star-wrapper--1QyBg"><span class="udlite-sr-only">Rating: 4.7 out of 5</span><span class="udlite-heading-sm star-rating--rating-number--2o8YM" aria-hidden="true" data-purpose="rating-number">4.7</span><svg aria-hidden="true" width="100%" height="100%" viewBox="0 0 70 14" fill="none" xmlns="http://www.w3.org/2000/svg"><mask id="u517-star-rating-mask--69" data-purpose="star-rating-mask"><rect x="0" y="0" width="90%" height="100%" fill="white"></rect></mask><g class="star-rating--star-filled--24lmQ" mask="url(#u517-star-rating-mask--69)" data-purpose="star-filled"><use xlink:href="#icon-rating-star" width="14" height="14" x="0"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="14"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="28"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="42"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="56"></use></g><g fill="transparent" class="star-rating--star-bordered--1EkpX" stroke-width="2" data-purpose="star-bordered"><use xlink:href="#icon-rating-star" width="12" height="12" x="1" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="15" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="29" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="43" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="57" y="1"></use></g></svg></span><span aria-label="4 reviews" class="udlite-text-xs course-card--reviews-text--1yloi">(4)</span></div><div class="price-text--container--103D9 course-card--price-text-container--XIYmk" data-purpose="price-text-container"><div class="price-text--price-part--2npPm course-card--discount-price--1bQ5Q udlite-heading-md" data-purpose="course-price-text"><span class="udlite-sr-only">Current price</span><span><span>₹385</span></span></div><div class="price-text--price-part--2npPm price-text--original-price--1sDdx course-card--list-price--3RTcj udlite-text-sm" data-purpose="original-price-container"><div data-purpose="course-old-price-text"><span class="udlite-sr-only">Original Price</span><span><s><span>₹4,480</span></s></span></div></div></div><div class="udlite-badge udlite-heading-xs udlite-badge-new ">New</div></div></div></a></div></div></div><div data-index="4" class="carousel--scroll-item--1O-L9"><div><div class="popper--popper--2r2To popper--popper-hover--3YydE"><a id="u517-popper-trigger--70" tabindex="0" aria-expanded="false" href="/course/azure-database-mysql/" class="udlite-custom-focus-visible browse-course-card--link--3KIkQ" style="display: block;"><div data-purpose="container" class="course-card--container--1QM2W course-card--medium--Fdbz0"><div class="course-card--image-wrapper--1F9ny"><img alt="" width="240" height="135" class="course-card--course-image--3QvbQ browse-course-card--image--35hYN" src="https://img-c.udemycdn.com/course/240x135/4165376_da46.jpg" srcset="https://img-c.udemycdn.com/course/240x135/4165376_da46.jpg 1x, https://img-c.udemycdn.com/course/480x270/4165376_da46.jpg 2x"></div><div class="course-card--main-content--2XqiY course-card--has-price-text--1c0ze"><div class="udlite-focus-visible-target udlite-heading-md course-card--course-title--vVEjC">Introduction to Azure Database for MySQL</div><div class="udlite-text-xs course-card--instructor-list--nH1OC" data-purpose="safely-set-inner-html:course-card:visible-instructors">Artemakis Artemiou</div><div class="course-card--row--29Y0w"><span class="star-rating--star-wrapper--1QyBg"><span class="udlite-sr-only">Rating: 5.0 out of 5</span><span class="udlite-heading-sm star-rating--rating-number--2o8YM" aria-hidden="true" data-purpose="rating-number">5.0</span><svg aria-hidden="true" width="100%" height="100%" viewBox="0 0 70 14" fill="none" xmlns="http://www.w3.org/2000/svg"><mask id="u517-star-rating-mask--72" data-purpose="star-rating-mask"><rect x="0" y="0" width="100%" height="100%" fill="white"></rect></mask><g class="star-rating--star-filled--24lmQ" mask="url(#u517-star-rating-mask--72)" data-purpose="star-filled"><use xlink:href="#icon-rating-star" width="14" height="14" x="0"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="14"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="28"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="42"></use><use xlink:href="#icon-rating-star" width="14" height="14" x="56"></use></g><g fill="transparent" class="star-rating--star-bordered--1EkpX" stroke-width="2" data-purpose="star-bordered"><use xlink:href="#icon-rating-star" width="12" height="12" x="1" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="15" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="29" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="43" y="1"></use><use xlink:href="#icon-rating-star" width="12" height="12" x="57" y="1"></use></g></svg></span><span aria-label="5 reviews" class="udlite-text-xs course-card--reviews-text--1yloi">(5)</span></div><div class="price-text--container--103D9 course-card--price-text-container--XIYmk" data-purpose="price-text-container"><div class="price-text--price-part--2npPm course-card--discount-price--1bQ5Q udlite-heading-md" data-purpose="course-price-text"><span class="udlite-sr-only">Current price</span><span><span>₹385</span></span></div><div class="price-text--price-part--2npPm price-text--original-price--1sDdx course-card--list-price--3RTcj udlite-text-sm" data-purpose="original-price-container"><div data-purpose="course-old-price-text"><span class="udlite-sr-only">Original Price</span><span><s><span>₹6,400</span></s></span></div></div></div><div class="udlite-badge udlite-heading-xs udlite-badge-new ">New</div></div></div></a></div></div></div><div data-index="5" class="carousel--scroll-item--1O-L9"><div><svg aria-label="Loading" focusable="false" class="udlite-icon udlite-icon-small udlite-icon-color-neutral udlite-loader"><use xlink:href="#icon-loading-spinner"></use></svg></div></div></div><button type="button" class="udlite-btn udlite-btn-large udlite-btn-black-solid udlite-btn-round udlite-heading-md udlite-btn-disabled udlite-btn-icon udlite-btn-icon-large udlite-btn-icon-round course-unit--pager-button--2mlVF carousel--button--3vRPI carousel--prev-button--1bSdY" data-pager-type="prev" disabled="" tabindex="-1"><svg aria-label="Previous" focusable="false" class="udlite-icon udlite-icon-large"><use xlink:href="#icon-previous"></use></svg></button><button type="button" class="udlite-btn udlite-btn-large udlite-btn-black-solid udlite-btn-round udlite-heading-md udlite-btn-icon udlite-btn-icon-large udlite-btn-icon-round course-unit--pager-button--2mlVF carousel--button--3vRPI carousel--next-button--1vy3Z" data-pager-type="next"><svg aria-label="Next" focusable="false" class="udlite-icon udlite-icon-large"><use xlink:href="#icon-next"></use></svg></button></div>

# %%
name=soup.find_all('a')#,class_='carousel--container--37Pr-')

# %%
len(name),type(name)
# Out:
# (276, bs4.element.ResultSet)

# %%
categories=[]
for i in name:
    categories.append(i.text)
categories=categories[1:]

# %%
categories
# Out:
# ['Development',
#  'Web Development',
#  'Data Science',
#  'Mobile Development',
#  'Programming Languages',
#  'Game Development',
#  'Database Design & Development',
#  'Software Testing',
#  'Software Engineering',
#  'Software Development Tools',
#  'No-Code Development',
#  'Business',
#  'Entrepreneurship',
#  'Communication',
#  'Management',
#  'Sales',
#  'Business Strategy',
#  'Operations',
#  'Project Management',
#  'Business Law',
#  'Business Analytics & Intelligence',
#  'Human Resources',
#  'Industry',
#  'E-Commerce',
#  'Media',
#  'Real Estate',
#  'Other Business',
#  'Finance & Accounting',
#  'Accounting & Bookkeeping',
#  'Compliance',
#  'Cryptocurrency & Blockchain',
#  'Economics',
#  'Finance',
#  'Finance Cert & Exam Prep',
#  'Financial Modeling & Analysis',
#  'Investing & Trading',
#  'Money Management Tools',
#  'Taxes',
#  'Other Finance & Accounting',
#  'IT & Software',
#  'IT Certifications',
#  'Network & Security',
#  'Hardware',
# ...

# %%
links=[]
for i in name:
    if 'href' in str(i):
        link=str(i)[str(i).find('href=')+6:str(i).find('>')-len(' tabindex="-1"')-1]
        links.append(udemy+link)
links=links[1:]
links
# Out:
# ['https://www.udemy.com//courses/development/',
#  'https://www.udemy.com//courses/development/web-development/',
#  'https://www.udemy.com//courses/development/data-science/',
#  'https://www.udemy.com//courses/development/mobile-apps/',
#  'https://www.udemy.com//courses/development/programming-languages/',
#  'https://www.udemy.com//courses/development/game-development/',
#  'https://www.udemy.com//courses/development/databases/',
#  'https://www.udemy.com//courses/development/software-testing/',
#  'https://www.udemy.com//courses/development/software-engineering/',
#  'https://www.udemy.com//courses/development/development-tools/',
#  'https://www.udemy.com//courses/development/no-code-development/',
#  'https://www.udemy.com//courses/business/',
#  'https://www.udemy.com//courses/business/entrepreneurship/',
#  'https://www.udemy.com//courses/business/communications/',
#  'https://www.udemy.com//courses/business/management/',
#  'https://www.udemy.com//courses/business/sales/',
# ...

# %%
category_link_df=pd.DataFrame(links,index=categories)

# %%
# category_link_df

# %%
category_link_df.columns=['link']
category_link_df.index.name='Category'
category_link_df
# Out:
#                                                                     link
# Category
# Development                  https://www.udemy.com//courses/development/
# Web Development        https://www.udemy.com//courses/development/web...
# Data Science           https://www.udemy.com//courses/development/dat...
# Mobile Development     https://www.udemy.com//courses/development/mob...
# Programming Languages  https://www.udemy.com//courses/development/pro...
# ...                                                                  ...
# \nTerms\n                                         https://www.udemy.com/
# \nPrivacy policy\n                               https://www.udemy.com//
# \nCookie settings\n    https://www.udemy.com/javascript:void(0);" sty...
# \nSitemap\n                                       https://www.udemy.com/
# \n\n                                     https://www.udemy.com//" style=
#
# [275 rows x 1 columns]

# %%
category_link_df.to_csv('Udemy_Category_link.csv')
